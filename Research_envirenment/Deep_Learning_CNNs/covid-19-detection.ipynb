# %% [markdown]
# <div style ="font-family:Trebuchet MS; background-color : #f8f0fa; border-left: 5px solid #1b4332; padding: 12px; border-radius: 50px 50px;">
#     <h2 style="color: #1b4332; font-size: 48px; text-align: center;">
#         <b> Covid 19 detection</b>
#         <hr style="border-top: 2px solid #264653;">
#     </h2>
#     <h3 style="font-size: 14px; color: #264653; text-align: left; "><strong> I hope this is very helpful. let's started .😊🌟</strong></h3>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Outline🌟🔻
# </h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <ul>
#         <li>🔻🌟Overview about the project 📋</li>
#         <li>🔻🌟Import libraries 📂</li>
#         <li>🔻🌟 Loading the dataset 🌟</li>
#         <li>🔻🌟 Data Visualization 🌟🔻</li>
#         <li>🔻🌟 Data preprocessing & Data Augmentation 🌟🔻</li>
#         <li>🔻🌟Building CNN Model 🚊</li>
#         <li>🔻🌟Testing & Save the model 🎯</li>
#         <li>🔻🌟 analysis</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Overview about the project 🌟🔻</h1>

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://yalibnan.com/wp-content/uploads/2020/10/COVID-19-Coronavirus-Animation.gif">

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <Strong>Objective:</Strong>
#     <hr>
#     <p>The goal of this project is to develop a machine learning model that can accurately classify MRI images into 3 categories related to Covid 19 disease:</p>
#     <li>Covid</li>
#     <li>Normal</li>
#     <li>Viral Pneumonia</li>
#     <br>
#     <Strong>What is Covid-19:</Strong>
#     <hr>
#     <p>COVID-19, also known as the coronavirus disease 2019, is caused by the severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). It was first identified in December 2019 in Wuhan, China, and has since led to a global pandemic. The disease is primarily spread through respiratory droplets, and symptoms can range from mild (or no symptoms) to severe respiratory illness. Common symptoms include fever, cough, and difficulty breathing. Severe cases can lead to pneumonia, acute respiratory distress syndrome (ARDS), multi-organ failure, and death.<p>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Import libraries 🌟🔻</h1>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import math
import os

import pickle

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# deep learning
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.vgg16 import VGG16

from tensorflow.keras.layers import RandomRotation, RandomContrast, RandomZoom, RandomFlip, RandomTranslation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.optimizers import Adam

# Training Model callbacks
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

# %matplotlib inline
plt.style.use('ggplot')

# %%
# general parameters 

plt.rcParams["figure.figsize"] = (18, 9)
plt.rcParams.update({'font.size': 15})

# %%
# Check if GPU is available
print(f'Tensorflow Version: {tf.__version__}')
print("GPU Available:", tf.config.list_physical_devices('GPU')[0])
# Out:
# Tensorflow Version: 2.6.4
# GPU Available: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Loading the dataset 🌟🔻</h1>

# %%
BATCH_SIZE = 64
height, width = 224, 224

# %%
path_train = '../input/covid19-image-dataset/Covid19-dataset/train'
path_test = '../input/covid19-image-dataset/Covid19-dataset/test'

def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=42,
        class_mode='binary',
        target_size=(height,width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator


train_ds = generate_data(path_train)
test_ds = generate_data(path_test)

total_image = np.concatenate([train_ds.labels,test_ds.labels])

print('\n\n',{'Normal_cases':len(np.where(total_image==0)[0]),
      'Viral_Pneumonia_cases':len(np.where(total_image==1)[0]),
             'Covid_cases':len(np.where(total_image==2)[0])})
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
#
#
#  {'Normal_cases': 90, 'Viral_Pneumonia_cases': 90, 'Covid_cases': 137}

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data Visualization 🌟🔻</h1>

# %%
def plot_pie_chart(distribution, title, ax):
    distribution_series = pd.Series(distribution)
    counts = distribution_series.value_counts()
    ax.pie(counts, labels=[f'{label} : {count}' for label, count in zip(counts.index, counts)],
           autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
    ax.axis('equal')  
    ax.set_title(title,pad=20)

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

plot_pie_chart(train_ds.labels, "Training Data Distribution", axes[0])
plot_pie_chart(test_ds.labels, "Testing Data Distribution", axes[1])

plt.tight_layout()
plt.show()

# %%
def image_plot(generator, image_numbers):
    img_feature = generator[0][0][:image_numbers]
    img_label = generator[0][1][:image_numbers]

    plt.figure(figsize=(20, 15))
    for i in range(image_numbers):
        ax = plt.subplot(math.ceil(image_numbers / 4), 4, i + 1)
        plt.imshow(img_feature[i])
        
        # Convert one-hot encoded labels to class indices if necessary
        if img_label.shape[-1] > 1:  # Check if labels are one-hot encoded
            class_idx = np.argmax(img_label[i])
        else:
            class_idx = int(img_label[i])
    
        labels = ["Normal", "Viral Pneumonia", "Covid"]
        plt.title(labels[class_idx])
        plt.axis("off")

    plt.show()

image_plot(train_ds, 15)

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻  Building CNN Model 🚊🔻</h1>

# %%
tf.keras.backend.clear_session()

input_shape = (height, width, 3)



base_model = VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)

base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])


model.compile(
    loss='sparse_categorical_crossentropy', 
    optimizer= Adam(0.001),
    metrics=['acc']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 14,912,579
# Trainable params: 197,891
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Callbacks 
    
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = LearningRateScheduler(exponential_decay_fn)

checkpoint = ModelCheckpoint("Covid19_model.keras", monitor='acc', verbose=1, mode='max',save_best_only=True)

early_stopping =EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Training  🌟🔻</h1>

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    shuffle=False, 
    verbose=True,
    callbacks=[checkpoint, early_stopping, lr_scheduler],
    epochs=50
)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 30s 5s/step - loss: 1.7517 - acc: 0.3825 - val_loss: 1.1161 - val_acc: 0.3030
#
# Epoch 00001: acc improved from -inf to 0.38247, saving model to Covid19_model.keras
# Epoch 2/50
# 4/4 [==============================] - 11s 3s/step - loss: 1.0619 - acc: 0.4024 - val_loss: 1.0118 - val_acc: 0.3939
#
# Epoch 00002: acc improved from 0.38247 to 0.40239, saving model to Covid19_model.keras
# Epoch 3/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.9482 - acc: 0.5339 - val_loss: 0.8384 - val_acc: 0.6970
#
# Epoch 00003: acc improved from 0.40239 to 0.53386, saving model to Covid19_model.keras
# Epoch 4/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.8147 - acc: 0.6653 - val_loss: 0.7021 - val_acc: 0.7273
#
# Epoch 00004: acc improved from 0.53386 to 0.66534, saving model to Covid19_model.keras
# Epoch 5/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.7302 - acc: 0.6932 - val_loss: 0.5835 - val_acc: 0.8939
#
# Epoch 00005: acc improved from 0.66534 to 0.69323, saving model to Covid19_model.keras
# Epoch 6/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.6271 - acc: 0.7331 - val_loss: 0.4983 - val_acc: 0.8333
#
# Epoch 00006: acc improved from 0.69323 to 0.73307, saving model to Covid19_model.keras
# Epoch 7/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.5951 - acc: 0.7769 - val_loss: 0.4493 - val_acc: 0.8485
#
# Epoch 00007: acc improved from 0.73307 to 0.77689, saving model to Covid19_model.keras
# Epoch 8/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.5667 - acc: 0.7689 - val_loss: 0.4217 - val_acc: 0.8333
#
# Epoch 00008: acc did not improve from 0.77689
# Epoch 9/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.5304 - acc: 0.7888 - val_loss: 0.4058 - val_acc: 0.8788
#
# Epoch 00009: acc improved from 0.77689 to 0.78884, saving model to Covid19_model.keras
# Epoch 10/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.5255 - acc: 0.7928 - val_loss: 0.3730 - val_acc: 0.9242
#
# Epoch 00010: acc improved from 0.78884 to 0.79283, saving model to Covid19_model.keras
# Epoch 11/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4362 - acc: 0.8685 - val_loss: 0.3561 - val_acc: 0.9091
#
# Epoch 00011: acc improved from 0.79283 to 0.86853, saving model to Covid19_model.keras
# Epoch 12/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.4597 - acc: 0.7968 - val_loss: 0.3363 - val_acc: 0.8939
#
# Epoch 00012: acc did not improve from 0.86853
# Epoch 13/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4385 - acc: 0.8486 - val_loss: 0.3341 - val_acc: 0.8788
#
# Epoch 00013: acc did not improve from 0.86853
# Epoch 14/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4026 - acc: 0.8446 - val_loss: 0.3382 - val_acc: 0.8939
#
# Epoch 00014: acc did not improve from 0.86853
# Epoch 15/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3976 - acc: 0.8566 - val_loss: 0.3170 - val_acc: 0.9091
#
# Epoch 00015: acc did not improve from 0.86853
# Epoch 16/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3795 - acc: 0.8685 - val_loss: 0.2978 - val_acc: 0.9091
#
# Epoch 00016: acc did not improve from 0.86853
# Epoch 17/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3678 - acc: 0.8765 - val_loss: 0.2815 - val_acc: 0.9242
#
# Epoch 00017: acc improved from 0.86853 to 0.87649, saving model to Covid19_model.keras
# Epoch 18/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3347 - acc: 0.8805 - val_loss: 0.2795 - val_acc: 0.9242
#
# Epoch 00018: acc improved from 0.87649 to 0.88048, saving model to Covid19_model.keras
# Epoch 19/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3404 - acc: 0.8805 - val_loss: 0.2765 - val_acc: 0.9242
#
# Epoch 00019: acc did not improve from 0.88048
# Epoch 20/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2905 - acc: 0.9124 - val_loss: 0.2668 - val_acc: 0.9394
#
# Epoch 00020: acc improved from 0.88048 to 0.91235, saving model to Covid19_model.keras
# Epoch 21/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3456 - acc: 0.8486 - val_loss: 0.2619 - val_acc: 0.9394
#
# Epoch 00021: acc did not improve from 0.91235
# Epoch 22/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3338 - acc: 0.8725 - val_loss: 0.2636 - val_acc: 0.9091
#
# Epoch 00022: acc did not improve from 0.91235
# Epoch 23/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3339 - acc: 0.9004 - val_loss: 0.2629 - val_acc: 0.9394
#
# Epoch 00023: acc did not improve from 0.91235
# Epoch 24/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2874 - acc: 0.8924 - val_loss: 0.2631 - val_acc: 0.9242
#
# Epoch 00024: acc did not improve from 0.91235
# Epoch 25/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3346 - acc: 0.8964 - val_loss: 0.2635 - val_acc: 0.9394
#
# Epoch 00025: acc did not improve from 0.91235
# Epoch 26/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3492 - acc: 0.9084 - val_loss: 0.2615 - val_acc: 0.9394
#
# Epoch 00026: acc did not improve from 0.91235
# Epoch 27/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2865 - acc: 0.9283 - val_loss: 0.2619 - val_acc: 0.9242
#
# Epoch 00027: acc improved from 0.91235 to 0.92829, saving model to Covid19_model.keras
# Epoch 28/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3181 - acc: 0.8685 - val_loss: 0.2576 - val_acc: 0.9394
#
# Epoch 00028: acc did not improve from 0.92829
# Epoch 29/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3022 - acc: 0.9163 - val_loss: 0.2547 - val_acc: 0.9394
#
# Epoch 00029: acc did not improve from 0.92829
# Epoch 30/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2984 - acc: 0.9124 - val_loss: 0.2522 - val_acc: 0.9394
#
# Epoch 00030: acc did not improve from 0.92829
# Epoch 31/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2908 - acc: 0.8964 - val_loss: 0.2509 - val_acc: 0.9242
#
# Epoch 00031: acc did not improve from 0.92829
# Epoch 32/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2754 - acc: 0.9124 - val_loss: 0.2497 - val_acc: 0.9242
#
# Epoch 00032: acc did not improve from 0.92829
# Epoch 33/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2839 - acc: 0.9124 - val_loss: 0.2472 - val_acc: 0.9242
#
# Epoch 00033: acc did not improve from 0.92829
# Epoch 34/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2697 - acc: 0.9243 - val_loss: 0.2450 - val_acc: 0.9242
#
# Epoch 00034: acc did not improve from 0.92829
# Epoch 35/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2851 - acc: 0.8924 - val_loss: 0.2427 - val_acc: 0.9242
#
# Epoch 00035: acc did not improve from 0.92829
# Epoch 36/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3050 - acc: 0.9004 - val_loss: 0.2411 - val_acc: 0.9394
#
# Epoch 00036: acc did not improve from 0.92829
# Epoch 37/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2777 - acc: 0.9243 - val_loss: 0.2401 - val_acc: 0.9394
#
# Epoch 00037: acc did not improve from 0.92829
# Epoch 38/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2719 - acc: 0.8964 - val_loss: 0.2398 - val_acc: 0.9394
#
# Epoch 00038: acc did not improve from 0.92829
# Epoch 39/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2726 - acc: 0.9243 - val_loss: 0.2395 - val_acc: 0.9394
#
# Epoch 00039: acc did not improve from 0.92829
# Epoch 40/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2943 - acc: 0.8884 - val_loss: 0.2395 - val_acc: 0.9394
#
# Epoch 00040: acc did not improve from 0.92829
# Epoch 41/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2990 - acc: 0.8884 - val_loss: 0.2393 - val_acc: 0.9394
#
# Epoch 00041: acc did not improve from 0.92829
# Epoch 42/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2403 - acc: 0.9243 - val_loss: 0.2388 - val_acc: 0.9394
#
# Epoch 00042: acc did not improve from 0.92829
# Epoch 43/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2715 - acc: 0.9203 - val_loss: 0.2381 - val_acc: 0.9394
#
# Epoch 00043: acc did not improve from 0.92829
# Epoch 44/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2907 - acc: 0.9283 - val_loss: 0.2375 - val_acc: 0.9394
#
# Epoch 00044: acc did not improve from 0.92829
# Epoch 45/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2731 - acc: 0.9084 - val_loss: 0.2371 - val_acc: 0.9394
#
# Epoch 00045: acc did not improve from 0.92829
# Epoch 46/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2542 - acc: 0.9243 - val_loss: 0.2369 - val_acc: 0.9394
#
# Epoch 00046: acc did not improve from 0.92829
# Epoch 47/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2827 - acc: 0.9124 - val_loss: 0.2369 - val_acc: 0.9394
#
# Epoch 00047: acc did not improve from 0.92829
# Epoch 48/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2269 - acc: 0.9243 - val_loss: 0.2367 - val_acc: 0.9394
#
# Epoch 00048: acc did not improve from 0.92829
# Epoch 49/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3105 - acc: 0.8884 - val_loss: 0.2366 - val_acc: 0.9394
#
# Epoch 00049: acc did not improve from 0.92829
# Epoch 50/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2555 - acc: 0.9203 - val_loss: 0.2366 - val_acc: 0.9394
#
# Epoch 00050: acc did not improve from 0.92829

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Analysis  🌟🔻</h1>

# %%
train_result = model.evaluate(train_ds)
test_result = model.evaluate(test_ds)

no_augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df
# Out:
# 4/4 [==============================] - 10s 2s/step - loss: 0.1808 - acc: 0.9562
# 2/2 [==============================] - 1s 11ms/step - loss: 0.2366 - acc: 0.9394
#          Train       Val
# Loss  0.180764  0.236559
# Acc   0.956175  0.939394

# %%
# Save the history
with open('training_history.pkl', 'wb') as file:
    pickle.dump(history.history, file)
    
    
# Load the training history
with open('training_history.pkl', 'rb') as file:
    history = pickle.load(file)

# %%
# Extract the data
acc = history['acc']
val_acc = history['val_acc']
loss = history['loss']
val_loss = history['val_loss']
epochs = range(len(acc))

# Plot accuracy
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing acuuracy")
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.legend(loc='upper left')
plt.show()

# Plot loss
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing loss")
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.legend(loc='upper left')
plt.show()

# %%
import math
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_ds.classes)/BATCH_SIZE)):
    xtest.append(test_ds[i][0]) 
    ytest= np.concatenate((ytest,test_ds[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90        20
#          1.0       0.94      0.85      0.89        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.94        66
#    macro avg       0.94      0.93      0.93        66
# weighted avg       0.94      0.94      0.94        66

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWFsMmxudnF2dm84aGs5NW9lcW9zaXdvM3N6eW55YzY4cjc5bm94MiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/smaaKxR6ZrQYQxHFfA/giphy.gif">

# %% [markdown]
#  <div align="center">
#   <a href="mailto:hassaneskikri@gmail.com">
#     <img src="https://img.shields.io/badge/Gmail-333333?style=for-the-badge&logo=gmail&logoColor=red" />
#   </a>
#   <a href="https://www.linkedin.com/in/hassane-skikri-3224bb255/" target="_blank">
#     <img src="https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white" target="_blank" />
#   </a>
#   <a href="https://hassaneskikri.github.io/skikriPortfolio/" target="_blank">
#      <img src="https://img.shields.io/badge/Portfolio-FF5722?style=for-the-badge&logo=todoist&logoColor=white" target="_blank" />
#   </a>
#    <a href="https://medium.com/@Hassane_01" target="_blank">
#     <img src="https://img.shields.io/badge/Medium-12100E?style=for-the-badge&logo=medium&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://www.kaggle.com/hassaneskikri" target="_blank">
#     <img src="https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=Kaggle&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://github.com/HassaneSkikri" target="_blank">
#     <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" target="_blank" />
#   </a>
